# %% [markdown]
# Hello...!!!!!!
#
# Welcome to my project.
#
# My project is based on a famous media company Netflix

# %%
# Loading necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ***Pandas***
#
# Pandas is a collection of programmes or a library that can be imported to analyse, clean, filter, modify, explore, model, etc. a dataset.

# %%
netflix = pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.info()                       #getting the information of our dataset set.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# From the above function we could get the complete information of our dataset.
# According to that information:
# * There are 8807 rows and 12 columns in the dataset.
# * There are null values in the dataset, which are to be altered.

# %%
netflix.isnull()               # finding if there is null value in the data.
netflix_1= netflix.dropna()    # Deleting the data with null value
netflix_1
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %% [markdown]
# Now, there are only 5332 rows in the dataframe after deleting the rows with null values. It also means that there were over 3000+ rows with null values. In order to have a genuine analysis, there should't be any null values in the dataframe.

# %% [markdown]
# Some best practices of Datatype

# %%
netflix['date_added'] = pd.to_datetime(netflix['date_added'])

# %%
netflix_1.sort_values('release_year') # Sorting data based on Release year
# Out:
#      show_id   type                                       title  \
# 8205   s8206  Movie                        The Battle of Midway
# 8640   s8641  Movie                            Tunisian Victory
# 7219   s7220  Movie                     Know Your Enemy - Japan
# 7294   s7295  Movie                          Let There Be Light
# 8587   s8588  Movie                                 Thunderbolt
# ...      ...    ...                                         ...
# 1151   s1152  Movie                Octonauts & the Ring of Fire
# 881     s882  Movie                              I Am All Girls
# 1156   s1157  Movie                                 A Week Away
# 1412   s1413  Movie                                    Wish You
# 1304   s1305  Movie  Animals on the Loose: A You vs. Wild Movie
#
#                                                director  \
# 8205                                          John Ford
# 8640  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
# ...

# %% [markdown]
# ***Q*** - Which is the oldest movie of TV show in Netflix?
#
# ***Ans*** - 'The Battle of Midway, is the oldest movie that was released in 1942. The duration of this movie is only 18mins.

# %%
netflix_1['country'].nunique()
# Out:
# 604

# %%
netflix_1['country']
# Out:
# 7       United States, Ghana, Burkina Faso, United Kin...
# 8                                          United Kingdom
# 9                                           United States
# 12                                Germany, Czech Republic
# 24                                                  India
#                               ...
# 8801                         United Arab Emirates, Jordan
# 8802                                        United States
# 8804                                        United States
# 8805                                        United States
# 8806                                                India
# Name: country, Length: 5332, dtype: object

# %%
x = netflix['country'].str.split(",",expand=True)

# %%
netflix[["country","other_1","other_2","other_3","other_4","other_5","other_6","other_7","other_8","other_9","other_10","other_11"]] = x
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_2 = netflix.drop(labels=["other_1","other_2","other_3","other_4","other_5","other_6","other_7","other_8","other_9","other_10","other_11"],axis=1)

# %%
netflix_2
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_2.isnull()               
netflix_1= netflix_2.dropna()    
netflix_1
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast               country  \
# ...

# %%
netflix_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   datetime64[ns]
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 541.5+ KB

# %%
netflix_1['country'].value_counts()
# Out:
# United States     2130
# India              910
# United Kingdom     347
# Canada             166
# France             145
#                   ...
# Paraguay             1
# Mozambique           1
# Cameroon             1
#                      1
# Croatia              1
# Name: country, Length: 77, dtype: int64

# %%
netflix_1['country'].nunique()
# Out:
# 77

# %% [markdown]
# ***Q*** - Mention the no. of contries whose movies or TV shows can be viewed in Netflix.
#
# ***Ans*** - There are over 77 country's movies and TV shows that can be viewed in Netflix.

# %% [markdown]
# ***Q*** - Which country has released the most movies and TV Shows?
#
# ***Ans*** - Out of 77 countries, United States has released over 2130 movies and TV shows.

# %% [markdown]
# ***Matplotlib***
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy.

# %%
plt.hist(netflix_1.release_year)

plt.title('Histogram showing the no. of movies and TV shows released in Netflix')

plt.xlabel('Year')
plt.ylabel('No. of Movies released')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ***Q*** - In which year most of the movies or TV shows released?
#
# ***Ans*** - Most of the movies and TV shows were released in 2020.

# %% [markdown]
# ***Q*** - What could be he reason for Netflix to release most of the movies and TV shows in 2020?
#
# ***Ans*** - The whole world witnessed COVID-19 pandemic form 2019. Most of us stayed at home to keep ourself awayfrom the decease. This could be a major reason for all the OTT platforms to release movies and TV shows. They also released the old ones as well to engage the public during the pandemic.

# %% [markdown]
# From the above analysis it is observed that:
#
# Netflix is a American based media house founded in 1997. Netflix is an OTT platform where most of the movies and TV shows can be viewed which released after 1942, by its subscribers. Movies and TV shows of all genre can be viewed here.
# There are 8800+ movies and TV shows in Netflix.
